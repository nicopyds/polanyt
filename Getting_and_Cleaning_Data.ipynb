# %% [markdown]
# # About the data

# %% [markdown]
# Download Data from this Page: https://www.nyc.gov/site/tlc/about/tlc-trip-record-data.page<br>
# Data Dictionary: https://www.nyc.gov/assets/tlc/downloads/pdf/data_dictionary_trip_records_yellow.pdf

# %% [markdown]
# # Imports

# %%
import os


import pandas as pd
import polars as pl

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# # GLOBAL_VARS

# %%
CWD = os.getcwd()

# %%
PATH_INPUT_FOLDER = os.path.join(CWD, "input")
PATH_OUTPUT_FOLDER = os.path.join(CWD, "output")

# %%
try:
    os.makedirs(PATH_OUTPUT_FOLDER)
except:
    pass

# %% [markdown]
# # Fixing Data Types

# %%
def get_file_types(input_folder):
    file_schemas = []

    for file_name in os.listdir(input_folder):
        file_path = os.path.join(input_folder, file_name)

        try:
            pldf_ = pl.read_parquet(file_path)
            schema_ = pldf_.schema

            columns = list(schema_.keys())
            types = list(schema_.values())
            file_names = [file_name for i in range(len(columns))]

            for c, t, f in zip(columns, types, file_names):
                file_schemas.append((c, t, f))

        except:
            print(file_path)

    return file_schemas

# %%
df = pd.DataFrame(
    data=get_file_types(input_folder=PATH_INPUT_FOLDER), columns=["Col", "Type", "File"]
)

# %%
df.head()
# Out:
#                      Col                                      Type  \
# 0               VendorID                                     Int32
# 1   tpep_pickup_datetime  Datetime(time_unit='ns', time_zone=None)
# 2  tpep_dropoff_datetime  Datetime(time_unit='ns', time_zone=None)
# 3        passenger_count                                     Int64
# 4          trip_distance                                   Float64
#
#                               File
# 0  yellow_tripdata_2023-06.parquet
# 1  yellow_tripdata_2023-06.parquet
# 2  yellow_tripdata_2023-06.parquet
# 3  yellow_tripdata_2023-06.parquet
# 4  yellow_tripdata_2023-06.parquet

# %%
(df["Col"].value_counts())
# Out:
# Col
# VendorID                 59
# tpep_pickup_datetime     59
# congestion_surcharge     59
# total_amount             59
# improvement_surcharge    59
# tolls_amount             59
# tip_amount               59
# mta_tax                  59
# extra                    59
# fare_amount              59
# payment_type             59
# DOLocationID             59
# PULocationID             59
# store_and_fwd_flag       59
# RatecodeID               59
# trip_distance            59
# passenger_count          59
# tpep_dropoff_datetime    59
# Airport_fee              34
# airport_fee              25
# cbd_congestion_fee       11
# Name: count, dtype: int64

# %%
df["Col"].nunique()
# Out:
# 21

# %%
(df["File"].value_counts())
# Out:
# File
# yellow_tripdata_2025-04.parquet    20
# yellow_tripdata_2025-07.parquet    20
# yellow_tripdata_2025-08.parquet    20
# yellow_tripdata_2025-10.parquet    20
# yellow_tripdata_2025-01.parquet    20
# yellow_tripdata_2025-11.parquet    20
# yellow_tripdata_2025-06.parquet    20
# yellow_tripdata_2025-09.parquet    20
# yellow_tripdata_2025-03.parquet    20
# yellow_tripdata_2025-05.parquet    20
# yellow_tripdata_2025-02.parquet    20
# yellow_tripdata_2024-12.parquet    19
# yellow_tripdata_2021-03.parquet    19
# yellow_tripdata_2021-08.parquet    19
# yellow_tripdata_2023-09.parquet    19
# yellow_tripdata_2024-02.parquet    19
# yellow_tripdata_2023-10.parquet    19
# yellow_tripdata_2024-09.parquet    19
# yellow_tripdata_2022-04.parquet    19
# yellow_tripdata_2023-06.parquet    19
# yellow_tripdata_2021-01.parquet    19
# yellow_tripdata_2023-12.parquet    19
# yellow_tripdata_2023-02.parquet    19
# yellow_tripdata_2023-01.parquet    19
# yellow_tripdata_2021-11.parquet    19
# yellow_tripdata_2024-10.parquet    19
# yellow_tripdata_2021-10.parquet    19
# yellow_tripdata_2024-01.parquet    19
# yellow_tripdata_2024-11.parquet    19
# yellow_tripdata_2024-08.parquet    19
# yellow_tripdata_2022-05.parquet    19
# yellow_tripdata_2021-09.parquet    19
# yellow_tripdata_2022-06.parquet    19
# yellow_tripdata_2021-12.parquet    19
# yellow_tripdata_2023-11.parquet    19
# yellow_tripdata_2021-06.parquet    19
# yellow_tripdata_2021-05.parquet    19
# yellow_tripdata_2022-09.parquet    19
# yellow_tripdata_2024-04.parquet    19
# yellow_tripdata_2021-04.parquet    19
# yellow_tripdata_2022-08.parquet    19
# yellow_tripdata_2024-05.parquet    19
# yellow_tripdata_2023-07.parquet    19
# yellow_tripdata_2022-01.parquet    19
# yellow_tripdata_2022-11.parquet    19
# yellow_tripdata_2024-07.parquet    19
# yellow_tripdata_2023-05.parquet    19
# yellow_tripdata_2022-07.parquet    19
# yellow_tripdata_2022-03.parquet    19
# yellow_tripdata_2023-04.parquet    19
# yellow_tripdata_2022-02.parquet    19
# yellow_tripdata_2022-12.parquet    19
# yellow_tripdata_2024-06.parquet    19
# yellow_tripdata_2021-07.parquet    19
# yellow_tripdata_2024-03.parquet    19
# yellow_tripdata_2021-02.parquet    19
# yellow_tripdata_2022-10.parquet    19
# yellow_tripdata_2023-08.parquet    19
# yellow_tripdata_2023-03.parquet    19
# Name: count, dtype: int64

# %%
(
    df.groupby(["Col"])
    .agg(
        nr_unique_types=("Type", lambda series: len(set(series))),
        unique_types=("Type", lambda series: set(series)),
    )
    .pipe(lambda df: df[df["nr_unique_types"] != 1])
)
# Out:
#                        nr_unique_types  \
# Col
# DOLocationID                         2
# PULocationID                         2
# RatecodeID                           2
# VendorID                             2
# passenger_count                      2
# tpep_dropoff_datetime                2
# tpep_pickup_datetime                 2
#
#                                                             unique_types
# Col
# DOLocationID                                              {Int64, Int32}
# PULocationID                                              {Int64, Int32}
# RatecodeID                                              {Int64, Float64}
# VendorID                                                  {Int64, Int32}
# passenger_count                                         {Int64, Float64}
# tpep_dropoff_datetime  {Datetime(time_unit='us', time_zone=None), Dat...
# tpep_pickup_datetime   {Datetime(time_unit='us', time_zone=None), Dat...

# %%
def get_default_rename_dict():
    rename_dict = {
        "VendorID": "VendorID",
        "tpep_pickup_datetime": "TpepPickupDatetime",
        "congestion_surcharge": "CongestionSurcharge",
        "total_amount": "TotalAmount",
        "improvement_surcharge": "ImprovementSurcharge",
        "tolls_amount": "TollsAmount",
        "tip_amount": "TipAmount",
        "mta_tax": "MtaTax",
        "extra": "Extra",
        "fare_amount": "FareAmount",
        "payment_type": "PaymentType",
        "DOLocationID": "DOLocationID",
        "PULocationID": "PULocationID",
        "store_and_fwd_flag": "StoreAndFwdFlag",
        "RatecodeID": "RatecodeID",
        "trip_distance": "TripDistance",
        "passenger_count": "PassengerCount",
        "tpep_dropoff_datetime": "TpepDropoffDatetime",
        "Airport_fee": "AirportFee",
    }

    return rename_dict

# %%
def standarize_files(input_folder, output_folder):
    for file_name in os.listdir(input_folder):
        if file_name != ".ipynb_checkpoints":
            file_path = os.path.join(input_folder, file_name)

            rename_dict = get_default_rename_dict()
            pldf = pl.read_parquet(file_path)
            columns = pldf.columns

            if "airport_fee" in columns:
                _ = rename_dict.pop("Airport_fee")
                rename_dict["airport_fee"] = "AirportFee"

            pldf = pldf.rename(rename_dict).with_columns(
                pl.col("VendorID").cast(pl.Int64),
                pl.col("DOLocationID").cast(pl.Int64),
                pl.col("PULocationID").cast(pl.Int64),
                pl.col("RatecodeID").cast(pl.Float64),
                pl.col("PassengerCount").cast(pl.Float64),
                pl.col("TpepDropoffDatetime").cast(pl.Datetime),
                pl.col("TpepPickupDatetime").cast(pl.Datetime),
            )
            output_path = os.path.join(output_folder, file_name)
            print(output_path)
            pldf.write_parquet(file=output_path)

# %%
standarize_files(input_folder=PATH_INPUT_FOLDER, output_folder=PATH_OUTPUT_FOLDER)
# Out:
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2023-06.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2022-10.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2025-02.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2021-05.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2022-09.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2024-04.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2025-03.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2021-04.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2022-08.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2024-05.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2023-07.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2022-01.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2022-11.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2025-11.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2025-01.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2024-07.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2021-06.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2023-05.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2025-08.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2022-03.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2023-04.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2025-09.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2022-02.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2022-12.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2025-10.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2024-06.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2021-07.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2024-03.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2021-02.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2021-12.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2025-05.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2023-08.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2022-07.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2023-11.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2023-01.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2022-06.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2023-10.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2024-02.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2024-12.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2021-03.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2025-04.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2023-09.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2024-09.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2022-04.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2021-08.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2023-12.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2023-02.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2021-01.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2021-11.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2024-10.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2025-06.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2021-10.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2024-01.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2024-11.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2025-07.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2024-08.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2022-05.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2021-09.parquet
# /Users/nicolaepopescul/code/polanyt/output/yellow_tripdata_2023-03.parquet

# %% [markdown]
# # Final Test

# %%
plldf = pl.scan_parquet(source=os.path.join(PATH_OUTPUT_FOLDER, "yellow_*.parquet"))

# %%
(plldf.describe())
# Out:
# shape: (9, 20)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ statistic ┆